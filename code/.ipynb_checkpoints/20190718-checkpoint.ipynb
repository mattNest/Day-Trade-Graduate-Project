# %% [markdown]
# ### 2019/07/19 meeting Notes
# -
# 1. raw data拿到就先分<span style="color:red">**大中小公司**</span>，再去做基本統計量
# 2. 第三部分的實作需要<span style="color:red">**價量資料**</span>

# %% [markdown]
# <img src="teacher.jpg" height="400" width="400">
# <img src="IMG_5317.JPG" height="400" width="400">

# %% [markdown]
# ### Document

# %% [markdown]
# <img src="data_split.png">

# %% [markdown]
# ### 第一部分：
# - 基本統計量說明: Raw Data在當沖前/當沖後的各種基本統計量陳述（平均數、中位數、min、max、標準差），對Raw Data有個基本的概念
#
# ### 第二部分：
# - 當沖前/當沖後的各種基本統計量的檢定（ex:現股當沖比重、日報酬率、週報酬率、月報酬率）
# - 做平均數檢定、中位數檢定，看看當沖前/當沖後這些基本統計量有沒有顯著變化
#
# ### 第三部分：
# - 政策面的研究。政府開放當沖是為了縮小spread、提高成交量、提高成交量週轉率。
# - 研究data做的回歸是不是符合政府所宣稱的?當沖真的有穩定市場嗎？對資本市場有貢獻嗎？
#
# ### 第四部分：
# - 市場面研究。有沒有其他在市場上面的因素會影響我們的回歸式？要控制這些變數，放入回歸式（很多x)

# %% [markdown]
# ### $ \Delta $ $上市公司日報酬率標準差_i$ = $a_0$ + $a_1$ * (上市公司現股當沖比重平均)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.stats.api as sms
import statsmodels.api as sm
import statsmodels.formula.api as smf
import warnings
import datetime as datetime
import json
import os
from datetime import timedelta
warnings.filterwarnings("ignore")
# %matplotlib inline

from sklearn.linear_model import LinearRegression
from scipy import stats

# %%
outside_test = pd.read_csv("20130613_20190620_data_utf8.csv")
outside_test.head(n=8)
# Out:
#       證券代碼 Data Field  2013/6/13  2013/6/14  2013/6/17  2013/6/18  2013/6/19  \
# 0  1101 台泥     日報酬率 %    -1.9685     0.1339     1.0695    -0.6614     0.0000
# 1  1101 台泥     週報酬率 %    -0.4001    -1.1889    -1.6905    -1.4436    -1.4436
# 2  1101 台泥     月報酬率 %    -3.3637    -4.3480    -4.3039    -4.9369    -4.9369
# 3  1101 台泥     現股當沖比重     0.0000     0.0000     0.0000     0.0000     0.0000
# 4  1102 亞泥     日報酬率 %    -0.8174    -0.2747     0.2755     0.2747    -0.5479
# 5  1102 亞泥     週報酬率 %    -0.5464    -2.6810    -2.5434    -0.5449    -1.0898
# 6  1102 亞泥     月報酬率 %    -2.8039    -3.7137    -3.9578    -3.6940    -4.2217
# 7  1102 亞泥     現股當沖比重     0.0000     0.0000     0.0000     0.0000     0.0000
#
#    2013/6/20  2013/6/21  2013/6/24  ...  2019/6/6  2019/6/10  2019/6/11  \
# 0    -0.6658    -5.7641    -1.5647  ...    0.3488     1.6222     0.3421
# 1    -0.1339    -6.0161    -8.4657  ...    0.5828     1.0368     2.0881
# 2    -4.9683   -11.0128   -11.6220  ...    2.0093     3.1763     3.5293
# 3     0.0000     0.0000     0.0000  ...   11.5700     7.1600     5.2100
# 4    -1.3774    -2.0950     0.2853  ...    0.4381     0.1091     1.8519
# 5    -1.6483    -3.4435    -3.4341  ...    1.6629     0.8791     3.2009
# 6    -5.1656    -7.5199    -5.8902  ...   10.2161    10.0718    12.1102
# 7     0.0000     0.0000     0.0000  ...   13.7300    10.9600    11.2500
#
#    2019/6/12  2019/6/13  2019/6/14  2019/6/17  2019/6/18  2019/6/19  2019/6/20
# 0    -0.5682     0.2286     0.2281     1.7065     1.1186     0.2212     0.2208
# 1     1.7441     1.6222     1.8540     1.9385     2.7274     3.5429     3.5349
# 2     2.9410     4.4047     5.7761     5.7988     6.9823     7.2190     7.2020
# 3     9.7500     8.4100     2.5800    15.1100     7.1200     9.9700     2.3800
# 4     0.0000    -1.2834     0.4334     0.8630     0.5348     0.8511     0.5274
# 5     2.4097     0.6544     1.0907     1.8520     0.5349     1.3905     3.2504
# 6    12.1102    11.4733    13.0487     6.8572     7.4286     8.3430     8.2956
# 7    10.7400    15.2700    12.5200    16.8800     8.4800    15.2700    21.9700
#
# [8 rows x 1481 columns]

# %% [markdown]
# ### tw_day_trade class

# %%
class tw_day_trade():
    def __init__(self):
        self.pos_1 = ""
        self.pos_2 = ""
        self.pos_3 = ""
        self.df_before = "" 
        self.df_after = ""  
        self.basic_stock_stats_info_dict = {}
        self.x = "" 
        self.y_daily = "" 
        self.y_weekly = "" 
        self.y_monthly = "" 

        """
        data basic info
        """
        self.day_trade_data = pd.read_csv("20130613_20190620_data_utf8.csv")
        self.company_num = len(self.day_trade_data)/4
        print("data 台灣上市公司總數: {} 間".format(self.company_num))
        print("data shape: {}".format(self.day_trade_data.shape))

        """
        當沖相關重要日期們
        """
        self.open_single_day_trade_date = '2014/1/6' # 開放單向當沖
        self.open_double_day_trade_date = '2014/6/30' # 開放雙向當沖
        self.tax_down_day_trade_date = '2017/4/28' # 調降當沖稅率
        
    
    def day_trade_split(self, date_1, date_2, date_3):
        """
        根據date_1, date_2, date_3來切割dataframe
        """
        tmp_arr = np.array(list(self.day_trade_data))
        self.pos_1 = np.where(tmp_arr==date_1)[0][0]
        self.pos_2 = np.where(tmp_arr==date_2)[0][0]
        self.pos_3 = np.where(tmp_arr==date_3)[0][0]
        print("date_1 pos: {}\ndate_2 pos: {}\ndate_3 pos: {}".format(self.pos_1,self.pos_2,self.pos_3))
        
        self.df_before = self.day_trade_data.iloc[:,self.pos_1:self.pos_2]
        self.df_after = self.day_trade_data.iloc[:,self.pos_2:(self.pos_3+1)]
        print("df_before shape: {}".format(self.df_before.shape))
        print("df after shape: {}".format(self.df_after.shape))
        
        
    def day_trade_stats(self):
        """
        第一部分：計算當沖前/當沖後的基本統計量，對Raw Data有個基本概念
        """
        
        # 平均數 (axis=1橫條往右apply func., axis=0是直條往下apply func.)
        self.df_before['mean_before'] = self.df_before.mean(axis=1)
        self.df_after['mean_after'] = self.df_after.mean(axis=1)
        
        test = self.df_before['mean_before']
        print(test)
        print(len(test))
        
        mean_before_daily = self.df_before['mean_before'][0::4].mean()
        mean_after_daily = self.df_after['mean_after'][0::4].mean()
        mean_before_weekly = self.df_before['mean_before'][1::4].mean()
        mean_after_weekly = self.df_after['mean_after'][1::4].mean()
        mean_before_monthly = self.df_before['mean_before'][2::4].mean()
        mean_after_monthly = self.df_after['mean_after'][2::4].mean()
        
        # 標準差 
        self.df_before['std_before'] = self.df_before.std(axis=1)
        self.df_after['std_after'] = self.df_after.std(axis=1)
        
        std_before_daily = self.df_before['std_before'][0::4].mean()
        std_after_daily = self.df_after['std_after'][0::4].mean()
        std_before_weekly = self.df_before['std_before'][1::4].mean()
        std_after_weekly = self.df_after['std_after'][1::4].mean()
        std_before_monthly = self.df_before['std_before'][2::4].mean()
        std_after_monthly = self.df_after['std_after'][2::4].mean()
        
        # 中位數
        self.df_before['median_before'] = self.df_before.median(axis=1)
        self.df_after['median_after'] = self.df_after.median(axis=1)
        
        median_before_daily = self.df_before['median_before'][0::4].mean()
        median_after_daily = self.df_after['median_after'][0::4].mean()
        median_before_weekly = self.df_before['median_before'][1::4].mean()
        median_after_weekly = self.df_after['median_after'][1::4].mean()
        median_before_monthly = self.df_before['median_before'][2::4].mean()
        median_after_monthly = self.df_after['median_after'][2::4].mean()
        
        # max
        max_before_daily = self.df_before['mean_before'][0::4].max()
        max_after_daily = self.df_after['mean_after'][0::4].max()
        max_before_weekly = self.df_before['mean_before'][1::4].max()
        max_after_weekly = self.df_after['mean_after'][1::4].max()
        max_before_monthly = self.df_before['mean_before'][2::4].max()
        max_after_monthly = self.df_after['mean_after'][2::4].max()
        
        # min
        min_before_daily = self.df_before['mean_before'][0::4].min()
        min_after_daily = self.df_after['mean_after'][0::4].min()
        min_before_weekly = self.df_before['mean_before'][1::4].min()
        min_after_weekly = self.df_after['mean_after'][1::4].min()
        min_before_monthly = self.df_before['mean_before'][2::4].min()
        min_after_monthly = self.df_after['mean_after'][2::4].min()
        
        
        # 存放基本統計量的dictionary
        self.basic_stock_stats_info_dict = {
            'mean':{'mean_before_daily':mean_before_daily,'mean_after_daily':mean_after_daily,
                   'mean_before_weekly':mean_before_weekly,'mean_after_weekly':mean_before_weekly,
                   'mean_before_monthly':mean_before_monthly,'mean_before_monthly':mean_before_monthly},
            
            'std':{'std_before_daily':std_before_daily, 'std_after_daily':std_after_daily,
                  'std_before_weekly':std_before_weekly, 'std_after_weekly':std_after_weekly,
                  'std_before_monthly':std_before_monthly, 'std_after_monthly':std_after_monthly},
            
            'median':{'median_before_daily':median_before_daily, 'median_after_daily':median_after_daily,
                  'median_before_weekly':median_before_weekly, 'median_after_weekly':median_after_weekly,
                  'median_before_monthly':median_before_monthly, 'median_after_monthly':median_after_monthly},
            
            'max':{'max_before_daily':max_before_daily, 'max_after_daily':max_after_daily,
                  'max_before_weekly':max_before_weekly, 'max_after_weekly':max_after_weekly,
                  'max_before_monthly':max_before_monthly, 'max_after_monthly':max_after_monthly},
            
            'min':{'min_before_daily':min_before_daily, 'min_after_daily':min_after_daily,
                  'min_before_weekly':min_before_weekly, 'min_after_weekly':min_after_weekly,
                  'min_before_monthly':min_before_monthly, 'min_after_monthly':min_after_monthly},

        }
        
        print (json.dumps(self.basic_stock_stats_info_dict, indent=2))
        
    
    def day_trade_calculate(self):
        """
        準備OLS的x和y
        """
        self.x = self.df_after['mean_after'][3::4]-self.df_before['mean_before'][3::4]
        self.y_daily = self.df_after['std_after'][0::4]-self.df_before['std_before'][0::4]
        self.y_weekly = self.df_after['std_after'][1::4]-self.df_before['std_before'][1::4]
        self.y_monthly = self.df_after['std_after'][2::4]-self.df_before['std_before'][2::4]
    
    def day_trade_OLS(self, date_freq):
        """
        根據傳進的date_freq，計算OLS(日/週/月)
        date_freq's value: 'daily','weekly','monthly'
        """
        if date_freq=='daily':
            self.x = sm.add_constant(self.x)
            self.y_daily = list(self.y_daily)
            model_daily = sm.OLS(self.y_daily, self.x).fit()
            print(model_daily.summary())

        if date_freq=='weekly':
            self.x = sm.add_constant(self.x)
            self.y_weekly = list(self.y_weekly)
            model_weekly = sm.OLS(self.y_weekly, self.x).fit()
            print(model_weekly.summary())

        if date_freq=='monthly':
            self.x = sm.add_constant(self.x)
            self.y_monthly = list(self.y_monthly)
            model_monthly = sm.OLS(self.y_monthly, self.x).fit()
            print(model_monthly.summary())

# %% [markdown]
# ### 2014/1/6開放單向當沖，前後各抓半年
# #### **<span style="color:green">pos_1 = 2013/6/13, pos_2 = 2014/1/6, pos_3 = 2014/6/30</span>**

# %%
data_1=tw_day_trade()
data_1.day_trade_split('2013/6/13','2014/1/6','2014/6/30')
data_1.day_trade_stats()
data_1.day_trade_calculate()
data_1.day_trade_OLS('daily')
data_1.day_trade_OLS('weekly')
data_1.day_trade_OLS('monthly')
# Out:
# data 台灣上市公司總數: 949.0 間
# data shape: (3796, 1481)
# date_1 pos: 2
# date_2 pos: 145
# date_3 pos: 260
# df_before shape: (3796, 143)
# df after shape: (3796, 116)
# 0       0.156810
# 1       0.861894
# 2       3.286883
# 3       0.000000
# 4       0.070137
# 5       0.368999
# 6       1.336310
# 7       0.000000
# 8       0.067669
# 9       0.298076
# 10      1.912097
# 11      0.000000
# 12      0.373745
# 13      1.778400
# 14      8.629051
# 15      0.000000
# 16      0.070683
# 17      0.293102
# 18      2.227292
# 19      0.000000
# 20      0.108421
# 21      0.556024
# 22      2.201441
# 23      0.000000
# 24      0.075921
# 25      0.381440
# 26      2.304257
# 27      0.000000
# 28      0.024615
# 29      0.172497
#           ...
# 3766    0.966558
# 3767    0.000000
# 3768    0.348920
# 3769    1.713836
# 3770    6.797857
# 3771    0.000000
# 3772   -0.074154
# 3773   -0.405136
# 3774   -1.698180
# 3775    0.000000
# 3776    0.285416
# 3777    1.469350
# 3778    5.962972
# 3779    0.000000
# 3780    0.049771
# 3781    0.333887
# 3782    1.307742
# 3783    0.000000
# 3784    0.123578
# 3785    0.607200
# 3786    3.045829
# 3787    0.000000
# 3788    0.011296
# 3789   -0.127359
# 3790   -0.485226
# 3791    0.000000
# 3792    0.175344
# 3793    0.757822
# 3794    2.321297
# 3795    0.000000
# Name: mean_before, Length: 3796, dtype: float64
# 3796
# {
#   "mean": {
#     "mean_before_daily": 0.09460335207469031,
#     "mean_after_daily": 0.08777297790777952,
#     "mean_before_weekly": 0.4410449998894677,
#     "mean_after_weekly": 0.4410449998894677,
#     "mean_before_monthly": 1.6103173889335112
#   },
#   "std": {
#     "std_before_daily": 1.6528694328768654,
#     "std_after_daily": 1.634751257121852,
#     "std_before_weekly": 3.6307358421075695,
#     "std_after_weekly": 3.509784619688007,
#     "std_before_monthly": 7.103563537181464,
#     "std_after_monthly": 6.936491375794543
#   },
#   "median": {
#     "median_before_daily": -0.00042051478553059135,
#     "median_after_daily": -0.010548943534028559,
#     "median_before_weekly": 0.10480199179113826,
#     "median_after_weekly": 0.16918428654482032,
#     "median_before_monthly": 0.8392261791941186,
#     "median_after_monthly": 1.47873654544967
#   },
#   "max": {
#     "max_before_daily": 0.966516083916084,
#     "max_after_daily": 1.4449189655172416,
#     "max_before_weekly": 4.811299300699301,
#     "max_after_weekly": 7.465105172413795,
#     "max_before_monthly": 23.69091678321678,
#     "max_after_monthly": 37.288900862068964
#   },
#   "min": {
#     "min_before_daily": -0.7100454545454546,
#     "min_after_daily": -0.7277327586206899,
#     "min_before_weekly": -3.4271846153846153,
#     "min_after_weekly": -3.1470939655172403,
#     "min_before_monthly": -15.606293006993011,
#     "min_after_monthly": -14.813574137931031
#   }
# }
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     9.564
# Date:                Thu, 25 Jul 2019   Prob (F-statistic):            0.00204
# Time:                        14:53:46   Log-Likelihood:                -1117.2
# No. Observations:                 949   AIC:                             2238.
# Df Residuals:                     947   BIC:                             2248.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0067      0.027      0.249      0.803      -0.046       0.059
# 0             -0.0580      0.019     -3.093      0.002      -0.095      -0.021
# ==============================================================================
# Omnibus:                      256.065   Durbin-Watson:                   1.935
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11798.637
# Skew:                           0.390   Prob(JB):                         0.00
# Kurtosis:                      20.256   Cond. No.                         1.61
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     8.059
# Date:                Thu, 25 Jul 2019   Prob (F-statistic):            0.00462
# Time:                        14:53:46   Log-Likelihood:                -2043.2
# No. Observations:                 949   AIC:                             4090.
# Df Residuals:                     947   BIC:                             4100.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0606      0.071     -0.854      0.393      -0.200       0.079
# 0             -0.1413      0.050     -2.839      0.005      -0.239      -0.044
# ==============================================================================
# Omnibus:                      256.623   Durbin-Watson:                   1.940
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2322.578
# Skew:                           0.965   Prob(JB):                         0.00
# Kurtosis:                      10.417   Cond. No.                         1.61
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     6.450
# Date:                Thu, 25 Jul 2019   Prob (F-statistic):             0.0113
# Time:                        14:53:46   Log-Likelihood:                -2896.0
# No. Observations:                 949   AIC:                             5796.
# Df Residuals:                     947   BIC:                             5806.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0344      0.174     -0.197      0.843      -0.377       0.308
# 0             -0.3105      0.122     -2.540      0.011      -0.550      -0.071
# ==============================================================================
# Omnibus:                      247.819   Durbin-Watson:                   1.843
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2026.849
# Skew:                           0.954   Prob(JB):                         0.00
# Kurtosis:                       9.901   Cond. No.                         1.61
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### 2014/6/30 開放雙向當沖，前後各抓半年
# #### **<span style="color:green">pos_1 = 2013/12/30, pos_2 = 2014/6/30, pos_3 = 2014/12/30</span>**

# %%
data_2 = tw_day_trade()
data_2.day_trade_split('2013/12/30','2014/6/30','2014/12/30')
data_2.day_trade_stats()
data_2.day_trade_calculate()
data_2.day_trade_OLS('daily')
data_2.day_trade_OLS('weekly')
data_2.day_trade_OLS('monthly')
# Out:
# data 台灣上市公司總數: 949.0 間
# data shape: (3796, 1481)
# date_1 pos: 141
# date_2 pos: 260
# date_3 pos: 389
# df_before shape: (3796, 119)
# df after shape: (3796, 130)
# 0       -0.008354
# 1       -0.070458
# 2       -0.174300
# 3        1.694118
# 4        0.053984
# 5        0.266682
# 6        0.716839
# 7        0.884118
# 8        0.011463
# 9        0.022368
# 10       0.222653
# 11       0.000000
# 12      -0.005073
# 13       0.168734
# 14      -0.458891
# 15       0.000000
# 16       0.069553
# 17       0.398199
# 18       1.697206
# 19       0.000000
# 20       0.249248
# 21       0.966927
# 22       4.069623
# 23       0.000000
# 24      -0.085064
# 25      -0.341155
# 26      -1.388455
# 27       0.000000
# 28      -0.108411
# 29      -0.375744
#           ...
# 3766     0.403166
# 3767     0.000000
# 3768     0.326269
# 3769     1.615255
# 3770     8.779425
# 3771     0.000000
# 3772     0.183764
# 3773     1.118729
# 3774     3.591101
# 3775     0.000000
# 3776     0.695227
# 3777     3.772394
# 3778    14.824650
# 3779     0.000000
# 3780    -0.051521
# 3781    -0.260817
# 3782    -0.958876
# 3783     2.291597
# 3784    -0.224906
# 3785    -1.010717
# 3786    -4.409424
# 3787     0.000000
# 3788     0.016222
# 3789     0.214786
# 3790    -0.553939
# 3791     0.000000
# 3792    -0.087808
# 3793    -0.245061
# 3794     0.263703
# 3795     0.000000
# Name: mean_before, Length: 3796, dtype: float64
# 3796
# {
#   "mean": {
#     "mean_before_daily": 0.09349509257865422,
#     "mean_after_daily": -0.0014445325788438703,
#     "mean_before_weekly": 0.5067351967130371,
#     "mean_after_weekly": 0.5067351967130371,
#     "mean_before_monthly": 2.2988817366356447
#   },
#   "std": {
#     "std_before_daily": 1.6400139127205873,
#     "std_after_daily": 1.7005381361728638,
#     "std_before_weekly": 3.535471001348419,
#     "std_after_weekly": 3.7665100297026757,
#     "std_before_monthly": 7.008057467716325,
#     "std_after_monthly": 7.001838124465493
#   },
#   "median": {
#     "median_before_daily": -0.006337460041972532,
#     "median_after_daily": -0.027065230702853396,
#     "median_before_weekly": 0.19159982998468092,
#     "median_after_weekly": -0.09137128183002416,
#     "median_before_monthly": 1.5559384484274277,
#     "median_after_monthly": -0.7467132211912048
#   },
#   "max": {
#     "max_before_daily": 1.4546252100840338,
#     "max_after_daily": 0.8389314960629923,
#     "max_before_weekly": 7.2485260504201685,
#     "max_after_weekly": 4.522435433070867,
#     "max_before_monthly": 36.73004621848739,
#     "max_after_monthly": 18.550629921259844
#   },
#   "min": {
#     "min_before_daily": -0.6174025210084035,
#     "min_after_daily": -0.58086062992126,
#     "min_before_weekly": -3.144451260504201,
#     "min_after_weekly": -3.3125582677165357,
#     "min_before_monthly": -14.610865546218486,
#     "min_after_monthly": -12.377414173228349
#   }
# }
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     7.689
# Date:                Thu, 25 Jul 2019   Prob (F-statistic):            0.00567
# Time:                        14:53:55   Log-Likelihood:                -1120.7
# No. Observations:                 949   AIC:                             2245.
# Df Residuals:                     947   BIC:                             2255.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0449      0.026      1.710      0.088      -0.007       0.096
# 0              0.0684      0.025      2.773      0.006       0.020       0.117
# ==============================================================================
# Omnibus:                      652.342   Durbin-Watson:                   1.795
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            30288.988
# Skew:                           2.545   Prob(JB):                         0.00
# Kurtosis:                      30.205   Cond. No.                         1.26
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     11.68
# Date:                Thu, 25 Jul 2019   Prob (F-statistic):           0.000658
# Time:                        14:53:55   Log-Likelihood:                -1976.1
# No. Observations:                 949   AIC:                             3956.
# Df Residuals:                     947   BIC:                             3966.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1835      0.065      2.840      0.005       0.057       0.310
# 0              0.2078      0.061      3.418      0.001       0.088       0.327
# ==============================================================================
# Omnibus:                      357.651   Durbin-Watson:                   1.845
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            17481.993
# Skew:                           0.941   Prob(JB):                         0.00
# Kurtosis:                      23.942   Cond. No.                         1.26
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     14.45
# Date:                Thu, 25 Jul 2019   Prob (F-statistic):           0.000153
# Time:                        14:53:55   Log-Likelihood:                -2821.5
# No. Observations:                 949   AIC:                             5647.
# Df Residuals:                     947   BIC:                             5657.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1352      0.157     -0.858      0.391      -0.444       0.174
# 0              0.5633      0.148      3.802      0.000       0.272       0.854
# ==============================================================================
# Omnibus:                      184.171   Durbin-Watson:                   1.901
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4516.247
# Skew:                           0.015   Prob(JB):                         0.00
# Kurtosis:                      13.687   Cond. No.                         1.26
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### 2014/6/30 開放雙向當沖，前後各抓一年
# #### **<span style="color:green">pos_1 = 2013/6/28, pos_2 = 2014/6/30, pos_3 = 2015/6/30</span>**

# %%
data_3 = tw_day_trade()
data_3.day_trade_split('2013/6/28','2014/6/30','2015/6/30')
data_3.day_trade_stats()
data_3.day_trade_calculate()
data_3.day_trade_OLS('daily')
data_3.day_trade_OLS('weekly')
data_3.day_trade_OLS('monthly')
# Out:
# data 台灣上市公司總數: 949.0 間
# data shape: (3796, 1481)
# date_1 pos: 13
# date_2 pos: 260
# date_3 pos: 506
# df_before shape: (3796, 247)
# df after shape: (3796, 247)
# 0        0.124196
# 1        0.637545
# 2        2.192343
# 3        0.816194
# 4        0.082124
# 5        0.434077
# 6        1.366975
# 7        0.425951
# 8        0.052826
# 9        0.263215
# 10       1.079655
# 11       0.000000
# 12       0.250133
# 13       1.252101
# 14       5.019063
# 15       0.000000
# 16       0.095160
# 17       0.481299
# 18       2.056768
# 19       0.000000
# 20       0.184685
# 21       0.787819
# 22       3.173437
# 23       0.000000
# 24       0.016490
# 25       0.066929
# 26       0.329442
# 27       0.000000
# 28      -0.029340
# 29      -0.039102
#           ...
# 3766     1.159015
# 3767     0.000000
# 3768     0.345813
# 3769     1.723917
# 3770     8.006383
# 3771     0.000000
# 3772     0.035700
# 3773     0.314533
# 3774     0.592134
# 3775     0.000000
# 3776     0.518866
# 3777     2.592679
# 3778    10.387143
# 3779     0.000000
# 3780     0.036540
# 3781     0.243859
# 3782     0.671914
# 3783     1.104049
# 3784    -0.027143
# 3785    -0.061906
# 3786    -0.312960
# 3787     0.000000
# 3788     0.031782
# 3789     0.171066
# 3790    -0.281346
# 3791     0.000000
# 3792     0.078099
# 3793     0.343412
# 3794     1.567586
# 3795     0.000000
# Name: mean_before, Length: 3796, dtype: float64
# 3796
# {
#   "mean": {
#     "mean_before_daily": 0.10297979334735478,
#     "mean_after_daily": -0.016855624125481524,
#     "mean_before_weekly": 0.527737205155224,
#     "mean_after_weekly": 0.527737205155224,
#     "mean_before_monthly": 2.002747358182276
#   },
#   "std": {
#     "std_before_daily": 1.6668403511772516,
#     "std_after_daily": 1.726236324343956,
#     "std_before_weekly": 3.703291204284982,
#     "std_after_weekly": 3.7899965413920027,
#     "std_before_monthly": 7.6631198639268545,
#     "std_after_monthly": 7.373464129731818
#   },
#   "median": {
#     "median_before_daily": -0.0049096944151738675,
#     "median_after_daily": -0.04109517136243501,
#     "median_before_weekly": 0.15129307090779553,
#     "median_after_weekly": -0.19111111307847778,
#     "median_before_monthly": 0.969146161951852,
#     "median_after_monthly": -0.6986982649985317
#   },
#   "max": {
#     "max_before_daily": 0.7479,
#     "max_after_daily": 0.7431577868852458,
#     "max_before_weekly": 4.025166801619433,
#     "max_after_weekly": 3.362147131147541,
#     "max_before_monthly": 17.1946012145749,
#     "max_after_monthly": 15.84547336065574
#   },
#   "min": {
#     "min_before_daily": -0.36495384615384624,
#     "min_after_daily": -0.5501758196721312,
#     "min_before_weekly": -1.825731174089069,
#     "min_after_weekly": -2.640545491803279,
#     "min_before_monthly": -8.407056275303642,
#     "min_after_monthly": -10.258631147540985
#   }
# }
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.4533
# Date:                Thu, 25 Jul 2019   Prob (F-statistic):              0.501
# Time:                        14:53:57   Log-Likelihood:                -1049.4
# No. Observations:                 949   AIC:                             2103.
# Df Residuals:                     947   BIC:                             2113.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0539      0.025      2.149      0.032       0.005       0.103
# 0              0.0109      0.016      0.673      0.501      -0.021       0.043
# ==============================================================================
# Omnibus:                      386.712   Durbin-Watson:                   1.762
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9732.915
# Skew:                           1.286   Prob(JB):                         0.00
# Kurtosis:                      18.477   Cond. No.                         1.75
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.3314
# Date:                Thu, 25 Jul 2019   Prob (F-statistic):              0.565
# Time:                        14:53:57   Log-Likelihood:                -1885.0
# No. Observations:                 949   AIC:                             3774.
# Df Residuals:                     947   BIC:                             3784.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0755      0.061      1.246      0.213      -0.043       0.194
# 0              0.0224      0.039      0.576      0.565      -0.054       0.099
# ==============================================================================
# Omnibus:                      245.603   Durbin-Watson:                   1.831
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4649.556
# Skew:                           0.674   Prob(JB):                         0.00
# Kurtosis:                      13.760   Cond. No.                         1.75
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                  0.009280
# Date:                Thu, 25 Jul 2019   Prob (F-statistic):              0.923
# Time:                        14:53:57   Log-Likelihood:                -2777.3
# No. Observations:                 949   AIC:                             5559.
# Df Residuals:                     947   BIC:                             5568.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2945      0.155     -1.899      0.058      -0.599       0.010
# 0              0.0096      0.100      0.096      0.923      -0.186       0.205
# ==============================================================================
# Omnibus:                      138.923   Durbin-Watson:                   1.885
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1629.212
# Skew:                          -0.173   Prob(JB):                         0.00
# Kurtosis:                       9.410   Cond. No.                         1.75
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### 2017/4/28 調降當沖稅率，前後各抓一年
# #### **<span style="color:green">pos_1 = 2016/4/28, pos_2 = 2017/4/28, pos_3 = 2018/4/27</span>**

# %%
data_4 = tw_day_trade()
data_4.day_trade_split('2016/4/28','2017/4/28','2018/4/27')
data_4.day_trade_stats()
data_4.day_trade_calculate()
data_4.day_trade_OLS('daily')
data_4.day_trade_OLS('weekly')
data_4.day_trade_OLS('monthly')
# Out:
# data 台灣上市公司總數: 949.0 間
# data shape: (3796, 1481)
# date_1 pos: 709
# date_2 pos: 953
# date_3 pos: 1199
# df_before shape: (3796, 244)
# df after shape: (3796, 247)
# 0       0.056067
# 1       0.266781
# 2       1.649248
# 3       3.828607
# 4       0.041682
# 5       0.195134
# 6       0.988857
# 7       2.641148
# 8       0.080683
# 9       0.295076
# 10      1.198403
# 11      1.825861
# 12      0.121865
# 13      0.588321
# 14      2.439920
# 15      1.105328
# 16      0.014234
# 17      0.024400
# 18      0.258802
# 19      0.851434
# 20      0.016281
# 21      0.072547
# 22      0.455898
# 23      0.982131
# 24      0.024072
# 25      0.095278
# 26      0.530577
# 27      4.807664
# 28     -0.035165
# 29     -0.172025
#           ...
# 3766    1.912000
# 3767    1.029508
# 3768    0.050307
# 3769    0.229749
# 3770    0.698109
# 3771    1.286557
# 3772    0.041012
# 3773    0.196164
# 3774    0.584765
# 3775    3.624836
# 3776   -0.027824
# 3777   -0.031884
# 3778   -0.295343
# 3779    4.594098
# 3780    0.008230
# 3781    0.090386
# 3782   -0.457835
# 3783    3.957213
# 3784   -0.053600
# 3785   -0.208326
# 3786   -0.973180
# 3787    2.296844
# 3788    0.051562
# 3789    0.256932
# 3790    1.575888
# 3791    5.278156
# 3792   -0.020631
# 3793   -0.112005
# 3794   -0.598129
# 3795    2.977377
# Name: mean_before, Length: 3796, dtype: float64
# 3796
# {
#   "mean": {
#     "mean_before_daily": 0.07824238672286618,
#     "mean_after_daily": 0.0537717533478667,
#     "mean_before_weekly": 0.36736691469882016,
#     "mean_after_weekly": 0.36736691469882016,
#     "mean_before_monthly": 1.4400727651194525
#   },
#   "std": {
#     "std_before_daily": 1.7583423302973558,
#     "std_after_daily": 1.8207571368868232,
#     "std_before_weekly": 3.7749447381318397,
#     "std_after_weekly": 3.9799561259053635,
#     "std_before_monthly": 7.631486740300063,
#     "std_after_monthly": 7.8155100006981595
#   },
#   "median": {
#     "median_before_daily": -0.00827248721691513,
#     "median_after_daily": -0.022403120693847773,
#     "median_before_weekly": 0.07053319564165904,
#     "median_after_weekly": -0.0196500693250513,
#     "median_before_monthly": 0.6395742594062096,
#     "median_after_monthly": 0.5840186733958184
#   },
#   "max": {
#     "max_before_daily": 1.1253422131147541,
#     "max_after_daily": 0.923642914979757,
#     "max_before_weekly": 5.815287295081968,
#     "max_after_weekly": 4.780445748987855,
#     "max_before_monthly": 20.23337336065574,
#     "max_after_monthly": 23.005874493927127
#   },
#   "min": {
#     "min_before_daily": -0.29669057377049174,
#     "min_after_daily": -0.45758097165991907,
#     "min_before_weekly": -1.3770372950819671,
#     "min_after_weekly": -2.112393522267207,
#     "min_before_monthly": -7.94567213114754,
#     "min_after_monthly": -9.318644534412957
#   }
# }
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.050
# Model:                            OLS   Adj. R-squared:                  0.049
# Method:                 Least Squares   F-statistic:                     50.16
# Date:                Thu, 25 Jul 2019   Prob (F-statistic):           2.77e-12
# Time:                        14:53:58   Log-Likelihood:                -1420.3
# No. Observations:                 949   AIC:                             2845.
# Df Residuals:                     947   BIC:                             2854.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1319      0.045     -2.959      0.003      -0.219      -0.044
# 0              0.0408      0.006      7.082      0.000       0.029       0.052
# ==============================================================================
# Omnibus:                      919.953   Durbin-Watson:                   1.879
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           579791.389
# Skew:                           3.487   Prob(JB):                         0.00
# Kurtosis:                     123.889   Cond. No.                         9.89
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.044
# Model:                            OLS   Adj. R-squared:                  0.043
# Method:                 Least Squares   F-statistic:                     44.01
# Date:                Thu, 25 Jul 2019   Prob (F-statistic):           5.48e-11
# Time:                        14:53:58   Log-Likelihood:                -2235.5
# No. Observations:                 949   AIC:                             4475.
# Df Residuals:                     947   BIC:                             4485.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2246      0.105     -2.135      0.033      -0.431      -0.018
# 0              0.0901      0.014      6.634      0.000       0.063       0.117
# ==============================================================================
# Omnibus:                      464.550   Durbin-Watson:                   1.904
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           240414.913
# Skew:                           0.831   Prob(JB):                         0.00
# Kurtosis:                      80.957   Cond. No.                         9.89
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.056
# Model:                            OLS   Adj. R-squared:                  0.055
# Method:                 Least Squares   F-statistic:                     55.86
# Date:                Thu, 25 Jul 2019   Prob (F-statistic):           1.77e-13
# Time:                        14:53:58   Log-Likelihood:                -2956.9
# No. Observations:                 949   AIC:                             5918.
# Df Residuals:                     947   BIC:                             5927.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.8510      0.225     -3.782      0.000      -1.293      -0.409
# 0              0.2172      0.029      7.474      0.000       0.160       0.274
# ==============================================================================
# Omnibus:                      497.933   Durbin-Watson:                   1.901
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            21594.934
# Skew:                           1.688   Prob(JB):                         0.00
# Kurtosis:                      26.124   Cond. No.                         9.89
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
