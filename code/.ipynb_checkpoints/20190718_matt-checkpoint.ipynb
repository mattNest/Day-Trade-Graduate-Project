# %% [markdown]
# <img src="teacher.jpg" height="400" width="400">

# %% [markdown]
# ### 第一部分：
# > 基本統計量說明: Raw Data在當沖前/當沖後的各種基本統計量陳述（平均數、中位數、min、max、標準差），對Raw Data有個基本的概念
# -
# ### 第二部分：
# > 當沖前/當沖後的各種基本統計量的檢定（ex:現股當沖比重、日報酬率、週報酬率、月報酬率），做平均數檢定、中位數檢定，看看當沖前/當沖後這些基本統計量有沒有顯著變化
# -
# ### 第三部分：
# > 政策面的研究。政府開放當沖是為了縮小spread、提高成交量、提高成交量週轉率。研究data做的回歸是不是符合政府所宣稱的?當沖真的有穩定市場嗎？對資本市場有貢獻嗎？
# -
# ### 第四部分：
# > 市場面研究。有沒有其他在市場上面的因素會影響我們的回歸式？要控制這些變數，放入回歸式（很多x)

# %% [markdown]
# ### $ \Delta $ $上市公司日報酬率標準差_i$ = $a_0$ + $a_1$ * (上市公司現股當沖比重平均)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.stats.api as sms
import statsmodels.api as sm
import statsmodels.formula.api as smf
# import seaborn as sns
import warnings
import datetime as datetime
import json
from datetime import timedelta
warnings.filterwarnings("ignore")
# %matplotlib inline

from sklearn.linear_model import LinearRegression
from scipy import stats

# %% [markdown]
# ### 選取2013/06/13 - 2019/06/20 每間台灣上市公司的日報酬率、週報酬率、月報酬率以及現股當沖比重的資料

# %%
day_trade_outside = pd.read_csv("20130613_20190620_data_utf8.csv")

# %%
day_trade_outside['test_mean'] = day_trade_data.mean(axis=1)
day_trade_outside.head(n=5)
# Out:
#       證券代碼 Data Field  2013/6/13  2013/6/14  2013/6/17  2013/6/18  2013/6/19  \
# 0  1101 台泥     日報酬率 %    -1.9685     0.1339     1.0695    -0.6614     0.0000
# 1  1101 台泥     週報酬率 %    -0.4001    -1.1889    -1.6905    -1.4436    -1.4436
# 2  1101 台泥     月報酬率 %    -3.3637    -4.3480    -4.3039    -4.9369    -4.9369
# 3  1101 台泥     現股當沖比重     0.0000     0.0000     0.0000     0.0000     0.0000
# 4  1102 亞泥     日報酬率 %    -0.8174    -0.2747     0.2755     0.2747    -0.5479
#
#    2013/6/20  2013/6/21  2013/6/24  ...  2019/6/10  2019/6/11  2019/6/12  \
# 0    -0.6658    -5.7641    -1.5647  ...     1.6222     0.3421    -0.5682
# 1    -0.1339    -6.0161    -8.4657  ...     1.0368     2.0881     1.7441
# 2    -4.9683   -11.0128   -11.6220  ...     3.1763     3.5293     2.9410
# 3     0.0000     0.0000     0.0000  ...     7.1600     5.2100     9.7500
# 4    -1.3774    -2.0950     0.2853  ...     0.1091     1.8519     0.0000
#
#    2019/6/13  2019/6/14  2019/6/17  2019/6/18  2019/6/19  2019/6/20  test_mean
# 0     0.2286     0.2281     1.7065     1.1186     0.2212     0.2208   0.048607
# 1     1.6222     1.8540     1.9385     2.7274     3.5429     3.5349   0.228457
# 2     4.4047     5.7761     5.7988     6.9823     7.2190     7.2020   0.876942
# 3     8.4100     2.5800    15.1100     7.1200     9.9700     2.3800   4.219417
# 4    -1.2834     0.4334     0.8630     0.5348     0.8511     0.5274   0.047438
#
# [5 rows x 1482 columns]

# %%
class tw_day_trade():
    def __init__(self):
        
        self.pos_1 = ""
        self.pos_2 = ""
        self.pos_3 = ""
        self.df_before = ""
        self.df_after = ""

        """
        data basic info
        """
        self.day_trade_data = pd.read_csv("20130613_20190620_data_utf8.csv")
        self.company_num = len(self.day_trade_data)/4 # 上市公司總數
        print("data 台灣上市公司總數: {} 間".format(self.company_num))
        print("data shape: {}".format(self.day_trade_data.shape))

        """
        當沖相關重要日期們
        """
        self.open_single_day_trade_date = '2014/1/6' # 開放單向當沖
        self.open_double_day_trade_date = '2014/6/30' # 開放雙向當沖
        self.tax_down_day_trade_date = '2017/4/28' # 調降當沖稅率

        
    
    def df_split(self, date_1, date_2, date_3):
        """
        根據date_1, date_2, date_3來切割dataframe
        """
        tmp_arr = np.array(list(self.day_trade_data))
        self.pos_1 = np.where(tmp_arr==date_1)[0][0]
        self.pos_2 = np.where(tmp_arr==date_2)[0][0]
        self.pos_3 = np.where(tmp_arr==date_3)[0][0]
        print("date_1 pos: {}\ndate_2 pos: {}\ndate_3 pos: {}".format(self.pos_1,self.pos_2,self.pos_3))
        
        self.df_before = self.day_trade_data.iloc[:,self.pos_1:self.pos_2]
        self.df_after = self.day_trade_data.iloc[:,self.pos_2:(self.pos_3+1)]
        print("df_before shape: {}".format(self.df_before.shape))
        print("df after shape: {}".format(self.df_after.shape))
        
        
    def basic_stock_stats_info(self):
        """
        第一部分：計算當沖前/當沖後的基本統計量，對Raw Data有個基本概念
        question: 銀華要的基本統計量的計算方式....???:)))???:)))
        """
        
        # 平均數 (axis=1橫條往右apply func., axis=0是直條往下apply func.)
        self.df_before['mean_before'] = self.df_before.mean(axis=1)
        self.df_after['mean_after'] = self.df_after.mean(axis=1)
        
        mean_before_daily = self.df_before['mean_before'][0::4].mean()
        mean_after_daily = self.df_after['mean_after'][0::4].mean()
        mean_before_weekly = self.df_before['mean_before'][1::4].mean()
        mean_after_weekly = self.df_after['mean_after'][1::4].mean()
        mean_before_monthly = self.df_before['mean_before'][2::4].mean()
        mean_after_monthly = self.df_after['mean_after'][2::4].mean()
        
        # 標準差 
        self.df_before['std_before'] = self.df_before.std(axis=1)
        self.df_after['std_after'] = self.df_after.std(axis=1)
        
        std_before_daily = self.df_before['std_before'][0::4].mean()
        std_after_daily = self.df_after['std_after'][0::4].mean()
        std_before_weekly = self.df_before['std_before'][1::4].mean()
        std_after_weekly = self.df_after['std_after'][1::4].mean()
        std_before_monthly = self.df_before['std_before'][2::4].mean()
        std_after_monthly = self.df_after['std_after'][2::4].mean()
        
        # 中位數
        self.df_before['median_before'] = self.df_before.median(axis=1)
        self.df_after['median_after'] = self.df_after.median(axis=1)
        
        median_before_daily = self.df_before['median_before'][0::4].mean()
        median_after_daily = self.df_after['median_after'][0::4].mean()
        median_before_weekly = self.df_before['median_before'][1::4].mean()
        median_after_weekly = self.df_after['median_after'][1::4].mean()
        median_before_monthly = self.df_before['median_before'][2::4].mean()
        median_after_monthly = self.df_after['median_after'][2::4].mean()
        
        # max
        max_before_daily = self.df_before['mean_before'][0::4].max()
        max_after_daily = self.df_after['mean_after'][0::4].max()
        max_before_weekly = self.df_before['mean_before'][1::4].max()
        max_after_weekly = self.df_after['mean_after'][1::4].max()
        max_before_monthly = self.df_before['mean_before'][2::4].max()
        max_after_monthly = self.df_after['mean_after'][2::4].max()
        
        # min
        min_before_daily = self.df_before['mean_before'][0::4].min()
        min_after_daily = self.df_after['mean_after'][0::4].min()
        min_before_weekly = self.df_before['mean_before'][1::4].min()
        min_after_weekly = self.df_after['mean_after'][1::4].min()
        min_before_monthly = self.df_before['mean_before'][2::4].min()
        min_after_monthly = self.df_after['mean_after'][2::4].min()
        
        
        basic_stock_stats_info_dict = {
            'mean':{'mean_before_daily':mean_before_daily,'mean_after_daily':mean_after_daily,
                   'mean_before_weekly':mean_before_weekly,'mean_after_weekly':mean_before_weekly,
                   'mean_before_monthly':mean_before_monthly,'mean_before_monthly':mean_before_monthly},
            
            'std':{'std_before_daily':std_before_daily, 'std_after_daily':std_after_daily,
                  'std_before_weekly':std_before_weekly, 'std_after_weekly':std_after_weekly,
                  'std_before_monthly':std_before_monthly, 'std_after_monthly':std_after_monthly},
            
            'median':{'median_before_daily':median_before_daily, 'median_after_daily':median_after_daily,
                  'median_before_weekly':median_before_weekly, 'median_after_weekly':median_after_weekly,
                  'median_before_monthly':median_before_monthly, 'median_after_monthly':median_after_monthly},
            
            'max':{'max_before_daily':max_before_daily, 'max_after_daily':max_after_daily,
                  'max_before_weekly':max_before_weekly, 'max_after_weekly':max_after_weekly,
                  'max_before_monthly':max_before_monthly, 'max_after_monthly':max_after_monthly},
            
            'min':{'min_before_daily':min_before_daily, 'min_after_daily':min_after_daily,
                  'min_before_weekly':min_before_weekly, 'min_after_weekly':min_after_weekly,
                  'min_before_monthly':min_before_monthly, 'min_after_monthly':min_after_monthly},

        }
        
        
        print (json.dumps(basic_stock_stats_info_dict, indent=2))

    def day_trade(self,str1, str2, str3):
        t1 = find_date_split(day_trade_data, str1)[0]
        t2 = find_date_split(day_trade_data, str2)[0]
        t3 = find_date_split(day_trade_data, str3)[0]

        day_trade_data_half_year_before = self.day_trade_data.iloc[:,t1:t2]
        day_trade_data_half_year_after = self.day_trade_data.iloc[:,t2:(t3+1)]

        # 計算每間公司的日報酬率/週報酬率/年報酬率 標準差
        day_trade_data_half_year_before['company_std_before'] = day_trade_data_half_year_before.std(axis=1)
        day_trade_data_half_year_after['company_std_after'] = day_trade_data_half_year_after.std(axis=1)

        # 計算每間公司的現股當沖比重平均
        day_trade_data_half_year_before['company_day_mean_before'] = day_trade_data_half_year_before.mean(axis=1)
        day_trade_data_half_year_after['company_mean_after'] = day_trade_data_half_year_after.mean(axis=1)

        # 計算x和y
        x = day_trade_data_half_year_after.iloc[3::4]['company_mean_after']
        y_day_return = day_trade_data_half_year_after.iloc[0::4]['company_std_after'] - day_trade_data_half_year_before.iloc[0::4]['company_std_before']
        y_week_return = day_trade_data_half_year_after.iloc[1::4]['company_std_after'] - day_trade_data_half_year_before.iloc[1::4]['company_std_before']
        y_month_return = day_trade_data_half_year_after.iloc[2::4]['company_std_after'] - day_trade_data_half_year_before.iloc[2::4]['company_std_before']

        result = [x, y_day_return, y_week_return, y_month_return]
        return result
    
    def OLS_test(x,y):
        """
        做OLS檢定顯著性
        """
        y = list(y)
        x = sm.add_constant(x) # a_0
        model = sm.OLS(y,x).fit()
        print(model.summary())

# %%
tmp = tw_day_trade()
# Out:
# data 台灣上市公司總數: 949.0 間
# data shape: (3796, 1481)

# %%
tmp.df_split('2013/6/13','2014/1/6','2014/6/30')
# Out:
# date_1 pos: 2
# date_2 pos: 145
# date_3 pos: 260
# df_before shape: (3796, 143)
# df after shape: (3796, 116)

# %%
tmp.basic_stock_stats_info()
# Out:
# {
#   "mean": {
#     "mean_before_daily": 0.09460335207469031,
#     "mean_after_daily": 0.08777297790777952,
#     "mean_before_weekly": 0.4410449998894677,
#     "mean_after_weekly": 0.4410449998894677,
#     "mean_before_monthly": 1.6103173889335112
#   },
#   "std": {
#     "std_before_daily": 1.6528694328768654,
#     "std_after_daily": 1.634751257121852,
#     "std_before_weekly": 3.6307358421075695,
#     "std_after_weekly": 3.509784619688007,
#     "std_before_monthly": 7.103563537181464,
#     "std_after_monthly": 6.936491375794543
#   },
#   "median": {
#     "median_before_daily": -0.00042051478553059135,
#     "median_after_daily": -0.010548943534028559,
#     "median_before_weekly": 0.10480199179113826,
#     "median_after_weekly": 0.16918428654482032,
#     "median_before_monthly": 0.8392261791941186,
#     "median_after_monthly": 1.47873654544967
#   },
#   "max": {
#     "max_before_daily": 0.966516083916084,
#     "max_after_daily": 1.4449189655172416,
#     "max_before_weekly": 4.811299300699301,
#     "max_after_weekly": 7.465105172413795,
#     "max_before_monthly": 23.69091678321678,
#     "max_after_monthly": 37.288900862068964
#   },
#   "min": {
#     "min_before_daily": -0.7100454545454546,
#     "min_after_daily": -0.7277327586206899,
#     "min_before_weekly": -3.4271846153846153,
#     "min_after_weekly": -3.1470939655172403,
#     "min_before_monthly": -15.606293006993011,
#     "min_after_monthly": -14.813574137931031
#   }
# }

# %% [markdown]
# ### 2014/1/6 開放單向當沖，前後各抓半年(2013/6/13 和 2014/6/30)，對日/週/月報酬的影響

# %%
result = day_trade('2013/6/13','2014/1/6','2014/6/30')
print(OLS_test(result[0],result[1]))
print(OLS_test(result[0],result[2]))
print(OLS_test(result[0],result[3]))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     9.528
# Date:                Mon, 24 Jun 2019   Prob (F-statistic):            0.00208
# Time:                        10:12:27   Log-Likelihood:                -1120.9
# No. Observations:                 949   AIC:                             2246.
# Df Residuals:                     947   BIC:                             2256.
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.0080      0.027      0.299      0.765      -0.045       0.061
# company_mean_after    -0.0581      0.019     -3.087      0.002      -0.095      -0.021
# ==============================================================================
# Omnibus:                      256.497   Durbin-Watson:                   1.935
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11785.905
# Skew:                           0.394   Prob(JB):                         0.00
# Kurtosis:                      20.246   Cond. No.                         1.61
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# None
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     8.020
# Date:                Mon, 24 Jun 2019   Prob (F-statistic):            0.00472
# Time:                        10:12:27   Log-Likelihood:                -2046.9
# No. Observations:                 949   AIC:                             4098.
# Df Residuals:                     947   BIC:                             4108.
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -0.0580      0.071     -0.814      0.416      -0.198       0.082
# company_mean_after    -0.1414      0.050     -2.832      0.005      -0.239      -0.043
# ==============================================================================
# Omnibus:                      257.215   Durbin-Watson:                   1.940
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2324.802
# Skew:                           0.968   Prob(JB):                         0.00
# Kurtosis:                      10.419   Cond. No.                         1.61
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# None
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     6.417
# Date:                Mon, 24 Jun 2019   Prob (F-statistic):             0.0115
# Time:                        10:12:27   Log-Likelihood:                -2899.8
# No. Observations:                 949   AIC:                             5804.
# Df Residuals:                     947   BIC:                             5813.
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -0.0290      0.175     -0.166      0.868      -0.372       0.314
# company_mean_after    -0.3107      0.123     -2.533      0.011      -0.551      -0.070
# ==============================================================================
# Omnibus:                      248.425   Durbin-Watson:                   1.843
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2029.355
# Skew:                           0.957   Prob(JB):                         0.00
# Kurtosis:                       9.903   Cond. No.                         1.61
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# None

# %% [markdown]
# ### 2014/6/30 開放雙向當沖，前後各抓半年(2013/12/30 和 2014/12/30)，對日報酬/週報酬/月報酬的影響

# %%
result = day_trade('2013/12/30','2014/6/30','2014/12/30')
print(OLS_test(result[0],result[1]))
print(OLS_test(result[0],result[2]))
print(OLS_test(result[0],result[3]))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     5.525
# Date:                Mon, 24 Jun 2019   Prob (F-statistic):             0.0190
# Time:                        10:12:32   Log-Likelihood:                -1125.6
# No. Observations:                 949   AIC:                             2255.
# Df Residuals:                     947   BIC:                             2265.
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.0416      0.027      1.543      0.123      -0.011       0.094
# company_mean_after     0.0293      0.012      2.351      0.019       0.005       0.054
# ==============================================================================
# Omnibus:                      652.679   Durbin-Watson:                   1.796
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            30009.414
# Skew:                           2.550   Prob(JB):                         0.00
# Kurtosis:                      30.072   Cond. No.                         2.32
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# None
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     9.080
# Date:                Mon, 24 Jun 2019   Prob (F-statistic):            0.00265
# Time:                        10:12:32   Log-Likelihood:                -1981.3
# No. Observations:                 949   AIC:                             3967.
# Df Residuals:                     947   BIC:                             3976.
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.1718      0.066      2.587      0.010       0.041       0.302
# company_mean_after     0.0926      0.031      3.013      0.003       0.032       0.153
# ==============================================================================
# Omnibus:                      358.077   Durbin-Watson:                   1.847
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            17307.281
# Skew:                           0.946   Prob(JB):                         0.00
# Kurtosis:                      23.835   Cond. No.                         2.32
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# None
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     10.60
# Date:                Mon, 24 Jun 2019   Prob (F-statistic):            0.00117
# Time:                        10:12:32   Log-Likelihood:                -2827.3
# No. Observations:                 949   AIC:                             5659.
# Df Residuals:                     947   BIC:                             5668.
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -0.1641      0.162     -1.013      0.311      -0.482       0.154
# company_mean_after     0.2439      0.075      3.255      0.001       0.097       0.391
# ==============================================================================
# Omnibus:                      183.317   Durbin-Watson:                   1.900
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4435.468
# Skew:                           0.025   Prob(JB):                         0.00
# Kurtosis:                      13.591   Cond. No.                         2.32
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# None

# %% [markdown]
# ### 2014/6/30 開放雙向當沖，前後各抓一年(2013/6/30 和 2015/6/30)，對日報酬/週報酬/月報酬的影響

# %%
result = day_trade('2013/6/28','2014/6/30','2015/6/30')
print(OLS_test(result[0],result[1]))
print(OLS_test(result[0],result[2]))
print(OLS_test(result[0],result[3]))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                   0.04552
# Date:                Mon, 24 Jun 2019   Prob (F-statistic):              0.831
# Time:                        10:12:52   Log-Likelihood:                -1051.5
# No. Observations:                 949   AIC:                             2107.
# Df Residuals:                     947   BIC:                             2117.
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.0578      0.025      2.290      0.022       0.008       0.107
# company_mean_after     0.0025      0.012      0.213      0.831      -0.021       0.026
# ==============================================================================
# Omnibus:                      385.686   Durbin-Watson:                   1.764
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9716.116
# Skew:                           1.280   Prob(JB):                         0.00
# Kurtosis:                      18.465   Cond. No.                         2.31
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# None
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                   0.07275
# Date:                Mon, 24 Jun 2019   Prob (F-statistic):              0.787
# Time:                        10:12:52   Log-Likelihood:                -1887.1
# No. Observations:                 949   AIC:                             3778.
# Df Residuals:                     947   BIC:                             3788.
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.0816      0.061      1.340      0.181      -0.038       0.201
# company_mean_after     0.0078      0.029      0.270      0.787      -0.049       0.064
# ==============================================================================
# Omnibus:                      244.802   Durbin-Watson:                   1.833
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4636.443
# Skew:                           0.669   Prob(JB):                         0.00
# Kurtosis:                      13.745   Cond. No.                         2.31
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# None
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                   0.01096
# Date:                Mon, 24 Jun 2019   Prob (F-statistic):              0.917
# Time:                        10:12:52   Log-Likelihood:                -2779.2
# No. Observations:                 949   AIC:                             5562.
# Df Residuals:                     947   BIC:                             5572.
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -0.2847      0.156     -1.827      0.068      -0.590       0.021
# company_mean_after    -0.0077      0.074     -0.105      0.917      -0.152       0.137
# ==============================================================================
# Omnibus:                      139.029   Durbin-Watson:                   1.887
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1628.492
# Skew:                          -0.175   Prob(JB):                         0.00
# Kurtosis:                       9.408   Cond. No.                         2.31
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# None

# %% [markdown]
# ### 2017/4/28 調降當沖稅率，前後各抓一年(2016/4/28 和 2018/4/28)，對日報酬/週報酬/月報酬的影響

# %%
result = day_trade('2016/4/28','2017/4/28','2018/4/27')
print(OLS_test(result[0],result[1]))
print(OLS_test(result[0],result[2]))
print(OLS_test(result[0],result[3]))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.023
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     22.68
# Date:                Mon, 24 Jun 2019   Prob (F-statistic):           2.22e-06
# Time:                        10:13:21   Log-Likelihood:                -1435.5
# No. Observations:                 949   AIC:                             2875.
# Df Residuals:                     947   BIC:                             2885.
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -0.1232      0.053     -2.330      0.020      -0.227      -0.019
# company_mean_after     0.0214      0.004      4.762      0.000       0.013       0.030
# ==============================================================================
# Omnibus:                      907.076   Durbin-Watson:                   1.882
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           509960.766
# Skew:                           3.428   Prob(JB):                         0.00
# Kurtosis:                     116.357   Cond. No.                         17.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# None
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                  0.016
# Method:                 Least Squares   F-statistic:                     16.43
# Date:                Mon, 24 Jun 2019   Prob (F-statistic):           5.46e-05
# Time:                        10:13:21   Log-Likelihood:                -2250.8
# No. Observations:                 949   AIC:                             4506.
# Df Residuals:                     947   BIC:                             4515.
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -0.1678      0.125     -1.345      0.179      -0.413       0.077
# company_mean_after     0.0431      0.011      4.053      0.000       0.022       0.064
# ==============================================================================
# Omnibus:                      464.041   Durbin-Watson:                   1.907
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           210819.045
# Skew:                           0.862   Prob(JB):                         0.00
# Kurtosis:                      75.997   Cond. No.                         17.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# None
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     14.41
# Date:                Mon, 24 Jun 2019   Prob (F-statistic):           0.000156
# Time:                        10:13:21   Log-Likelihood:                -2978.8
# No. Observations:                 949   AIC:                             5962.
# Df Residuals:                     947   BIC:                             5971.
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -0.5684      0.269     -2.115      0.035      -1.096      -0.041
# company_mean_after     0.0869      0.023      3.796      0.000       0.042       0.132
# ==============================================================================
# Omnibus:                      484.428   Durbin-Watson:                   1.916
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            17345.042
# Skew:                           1.676   Prob(JB):                         0.00
# Kurtosis:                      23.674   Cond. No.                         17.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# None

# %% [markdown]
# ### 2017/4/28 調降當沖稅率，前後各抓兩年(2015/4/28 和 2019/4/28)，對日報酬/週報酬/月報酬的影響

# %%
result = day_trade('2015/4/28','2017/4/28','2019/4/26')
print(OLS_test(result[0],result[1]))
print(OLS_test(result[0],result[2]))
print(OLS_test(result[0],result[3]))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                  0.030
# Method:                 Least Squares   F-statistic:                     30.62
# Date:                Mon, 24 Jun 2019   Prob (F-statistic):           4.06e-08
# Time:                        10:13:32   Log-Likelihood:                -1284.0
# No. Observations:                 949   AIC:                             2572.
# Df Residuals:                     947   BIC:                             2582.
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -0.2985      0.046     -6.489      0.000      -0.389      -0.208
# company_mean_after     0.0198      0.004      5.533      0.000       0.013       0.027
# ==============================================================================
# Omnibus:                      892.445   Durbin-Watson:                   1.595
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           155694.894
# Skew:                           3.705   Prob(JB):                         0.00
# Kurtosis:                      65.310   Cond. No.                         19.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# None
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.028
# Model:                            OLS   Adj. R-squared:                  0.027
# Method:                 Least Squares   F-statistic:                     27.16
# Date:                Mon, 24 Jun 2019   Prob (F-statistic):           2.30e-07
# Time:                        10:13:32   Log-Likelihood:                -2119.9
# No. Observations:                 949   AIC:                             4244.
# Df Residuals:                     947   BIC:                             4253.
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -0.6633      0.111     -5.977      0.000      -0.881      -0.445
# company_mean_after     0.0449      0.009      5.212      0.000       0.028       0.062
# ==============================================================================
# Omnibus:                      578.827   Durbin-Watson:                   1.654
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            51160.763
# Skew:                           1.910   Prob(JB):                         0.00
# Kurtosis:                      38.767   Cond. No.                         19.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# None
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.037
# Model:                            OLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     36.16
# Date:                Mon, 24 Jun 2019   Prob (F-statistic):           2.59e-09
# Time:                        10:13:32   Log-Likelihood:                -2921.3
# No. Observations:                 949   AIC:                             5847.
# Df Residuals:                     947   BIC:                             5856.
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -1.4795      0.258     -5.729      0.000      -1.986      -0.973
# company_mean_after     0.1206      0.020      6.014      0.000       0.081       0.160
# ==============================================================================
# Omnibus:                      417.405   Durbin-Watson:                   1.725
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5048.561
# Skew:                           1.674   Prob(JB):                         0.00
# Kurtosis:                      13.792   Cond. No.                         19.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# None
